# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import dask.array as da

# %%
loc = r'C:\Users\formanj\GitHub\FISH_Processing\Parameter_Tuning\DUSP1_conc_sweep_R2_0min_071422\DUSP1_conc_sweep_R2_0min_071422.h5'
h5_file = h5py.File(loc, 'r') # making this read is important otherwise you may get WINERROR 33

# %%
level = 1

def print_group(name, obj):
    # Calculate current level based on the name depth
    current_level = name.count('/')
    if current_level <= level:
        print("  " * 2 * current_level + f"- {name}")

h5_file.visititems(print_group)
# Out:
# - Analysis_ER_Dec0324_2024-12-03
#     - Analysis_ER_Dec0324_2024-12-03/bigfish_threshold
#     - Analysis_ER_Dec0324_2024-12-03/df_clusterresults
#     - Analysis_ER_Dec0324_2024-12-03/df_spotresults
#     - Analysis_ER_Dec0324_2024-12-03/parameters
# - masks
# - metadata
# - raw_images

# %%
df = pd.read_hdf(loc, key='Analysis_ER_Dec0324_2024-12-03/df_spotresults')
df['NAS_location'][0]
# Out:
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# 0    smFISH_images/Eric_smFISH_images/20220718/DUSP...
# Name: NAS_location, dtype: object

# %%
spots = pd.read_hdf(loc, key='Analysis_demo_2024-11-20/df_spotresults')
spots

# %%
# TODO For undergrad project spot classification 

# load in image
d = h5_file['raw_images']
# p, t, c, z, y, x
images = da.from_array(d, (1,1,-1,-1,-1,-1))

# display plot
plt.imshow(np.max(images[0, 0, 0, :, :, :], axis=0))
plt.show()

x, y, z = spots.iloc[6][['x_px', 'y_px', 'z_px']]


plt.imshow(np.max(images[0, 0, 0, :, y-2:y+3, x-2:x+3], axis=0))
plt.show()

# %%
# TODO For undergrad project spot classification 

# load in image
d = h5_file['masks']
# p, t, c, z, y, x
masks = da.from_array(d, (1,1,-1,-1,-1,-1))
print(masks.shape)

# display plot
plt.imshow(np.max(masks[0, 0, 2, :, :, :], axis=0))
plt.show()

np.unique(masks[0, 0, 2, :, :, :].flatten().compute())
