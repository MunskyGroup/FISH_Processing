# %% [markdown]
# # Create a virtual env
# If using vscode hit select Kernel, (you many need to click select another kernel) click python enviroments, then create python enviroment, then click Venv.
# This will create a .venv folder in the repository and will be the env used throughout the process.
# Then go through the following cells and install them to the enviroment.

# %% [markdown]
# Torch

# %%
# for cluster
! pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# jacks windows:
# ! pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124

# for mac: 
# ! pip3 install torch torchvision torchaudio

# for older windows/cuda:
# ! pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %% [markdown]
# The rest

# %%
! pip install numpy
! pip install matplotlib
